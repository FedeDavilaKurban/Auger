# %%
import numpy as np
from astropy.io import ascii
import matplotlib.pyplot as plt

clusters = ascii.read('../data/Local_Clusters_z0.055.txt')
plt.hist(clusters['z']*3e5, bins=30)
plt.axvline(8000, color='red', linestyle='--', label='cz_min')
plt.axvline(9400, color='red', linestyle='--', label='cz_max')

plt.show()
